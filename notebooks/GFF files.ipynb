# %%
# %load_ext autoreload
# %autoreload 2

# %%
from clodius.tiles.gff import tileset_info

filename = "/Users/pete/resgen-data/sacCer3/genomic.short.gff"
chromsizes = {"NC_001133.9": 230218}
tsinfo = tileset_info(filename, chromsizes)

# %%
from clodius.tiles.gff import tiles
from pandas import Series
tile = tiles(filename, ["x.0.0"], Series(chromsizes))
tile
# Out:
# /Users/pete/projects/resgen/rhodius/clodius/tiles/bigwig.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yield cid, start, chromsizes[cid]
# [('x.0.0',
#   {'genes': {'gene_rna-NM_001180043.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001180043.1',
#       'chrom': 'NC_001133.9',
#       'start': 1807,
#       'end': 2169,
#       'strand': '-',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009332.1',
#        'Parent': 'rna-NM_001180043.1',
#        'Dbxref': 'SGD:S000002142,GeneID:851229,GenBank:NP_009332.1',
#        'Name': 'NP_009332.1',
#        'Note': 'hypothetical protein%3B member of the seripauperin multigene family encoded mainly in subtelomeric regions',
#        'experiment': 'EXISTENCE:mutant phenotype:GO:0030437 ascospore formation [PMID:12586695]',
#        'gbkey': 'CDS',
#        'gene': 'PAU8',
#        'locus_tag': 'YAL068C',
#        'product': 'seripauperin PAU8',
#        'protein_id': 'NP_009332.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001180043.1',
#        'chrom': 'NC_001133.9',
#        'start': 1807,
#        'end': 2169,
#        'strand': '-',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009332.1',
#         'Parent': 'rna-NM_001180043.1',
#         'Dbxref': 'SGD:S000002142,GeneID:851229,GenBank:NP_009332.1',
#         'Name': 'NP_009332.1',
#         'Note': 'hypothetical protein%3B member of the seripauperin multigene family encoded mainly in subtelomeric regions',
#         'experiment': 'EXISTENCE:mutant phenotype:GO:0030437 ascospore formation [PMID:12586695]',
#         'gbkey': 'CDS',
#         'gene': 'PAU8',
#         'locus_tag': 'YAL068C',
#         'product': 'seripauperin PAU8',
#         'protein_id': 'NP_009332.1'},
#        'parent_gene_id': 'gene_rna-NM_001180043.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009332.1',
#          'chrom': 'NC_001133.9',
#          'start': 1807,
#          'end': 2169,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009332.1',
#           'Parent': 'rna-NM_001180043.1',
#           'Dbxref': 'SGD:S000002142,GeneID:851229,GenBank:NP_009332.1',
#           'Name': 'NP_009332.1',
#           'Note': 'hypothetical protein%3B member of the seripauperin multigene family encoded mainly in subtelomeric regions',
#           'experiment': 'EXISTENCE:mutant phenotype:GO:0030437 ascospore formation [PMID:12586695]',
#           'gbkey': 'CDS',
#           'gene': 'PAU8',
#           'locus_tag': 'YAL068C',
#           'product': 'seripauperin PAU8',
#           'protein_id': 'NP_009332.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009332.1',
#          'chrom': 'NC_001133.9',
#          'start': 1807,
#          'end': 2169,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009332.1',
#           'Parent': 'rna-NM_001180043.1',
#           'Dbxref': 'SGD:S000002142,GeneID:851229,GenBank:NP_009332.1',
#           'Name': 'NP_009332.1',
#           'Note': 'hypothetical protein%3B member of the seripauperin multigene family encoded mainly in subtelomeric regions',
#           'experiment': 'EXISTENCE:mutant phenotype:GO:0030437 ascospore formation [PMID:12586695]',
#           'gbkey': 'CDS',
#           'gene': 'PAU8',
#           'locus_tag': 'YAL068C',
#           'product': 'seripauperin PAU8',
#           'protein_id': 'NP_009332.1'}}]}]},
#     'gene_rna-NM_001184582.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001184582.1',
#       'chrom': 'NC_001133.9',
#       'start': 2480,
#       'end': 2707,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_878038.1',
#        'Parent': 'rna-NM_001184582.1',
#        'Dbxref': 'SGD:S000028593,GeneID:1466426,GenBank:NP_878038.1',
#        'Name': 'NP_878038.1',
#        'Note': 'hypothetical protein%3B identified by gene-trapping%2C microarray-based expression analysis%2C and genome-wide homology searching',
#        'gbkey': 'CDS',
#        'locus_tag': 'YAL067W-A',
#        'product': 'uncharacterized protein',
#        'protein_id': 'NP_878038.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001184582.1',
#        'chrom': 'NC_001133.9',
#        'start': 2480,
#        'end': 2707,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_878038.1',
#         'Parent': 'rna-NM_001184582.1',
#         'Dbxref': 'SGD:S000028593,GeneID:1466426,GenBank:NP_878038.1',
#         'Name': 'NP_878038.1',
#         'Note': 'hypothetical protein%3B identified by gene-trapping%2C microarray-based expression analysis%2C and genome-wide homology searching',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAL067W-A',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_878038.1'},
#        'parent_gene_id': 'gene_rna-NM_001184582.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_878038.1',
#          'chrom': 'NC_001133.9',
#          'start': 2480,
#          'end': 2707,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_878038.1',
#           'Parent': 'rna-NM_001184582.1',
#           'Dbxref': 'SGD:S000028593,GeneID:1466426,GenBank:NP_878038.1',
#           'Name': 'NP_878038.1',
#           'Note': 'hypothetical protein%3B identified by gene-trapping%2C microarray-based expression analysis%2C and genome-wide homology searching',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL067W-A',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_878038.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_878038.1',
#          'chrom': 'NC_001133.9',
#          'start': 2480,
#          'end': 2707,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_878038.1',
#           'Parent': 'rna-NM_001184582.1',
#           'Dbxref': 'SGD:S000028593,GeneID:1466426,GenBank:NP_878038.1',
#           'Name': 'NP_878038.1',
#           'Note': 'hypothetical protein%3B identified by gene-trapping%2C microarray-based expression analysis%2C and genome-wide homology searching',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL067W-A',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_878038.1'}}]}]},
#     'gene_rna-NM_001178208.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178208.1',
#       'chrom': 'NC_001133.9',
#       'start': 7235,
#       'end': 9016,
#       'strand': '-',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009333.1',
#        'Parent': 'rna-NM_001178208.1',
#        'Dbxref': 'SGD:S000000062,GeneID:851230,GenBank:NP_009333.1',
#        'Name': 'NP_009333.1',
#        'Note': 'High affinity dipeptide transmembrane transporter%3B involved in the transport of the gamma-Glu-met dipeptide across the plasma membrane%3B member of the allantoate transporter subfamily of the major facilitator superfamily%3B transcriptionally upregulated in cells grown on gamma-Glu-met%3B mutation confers resistance to ethionine sulfoxide',
#        'experiment': 'EXISTENCE:direct assay:GO:0005886 plasma membrane [PMID:40288644],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:genetic interaction:GO:0042938 dipeptide transport [PMID:40288644],EXISTENCE:genetic interaction:GO:0071916 dipeptide transmembrane transporter activity [PMID:40288644],EXISTENCE:mutant phenotype:GO:0055085 transmembrane transport [PMID:8893857]',
#        'gbkey': 'CDS',
#        'gene': 'SEO1',
#        'locus_tag': 'YAL067C',
#        'product': 'putative permease SEO1',
#        'protein_id': 'NP_009333.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178208.1',
#        'chrom': 'NC_001133.9',
#        'start': 7235,
#        'end': 9016,
#        'strand': '-',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009333.1',
#         'Parent': 'rna-NM_001178208.1',
#         'Dbxref': 'SGD:S000000062,GeneID:851230,GenBank:NP_009333.1',
#         'Name': 'NP_009333.1',
#         'Note': 'High affinity dipeptide transmembrane transporter%3B involved in the transport of the gamma-Glu-met dipeptide across the plasma membrane%3B member of the allantoate transporter subfamily of the major facilitator superfamily%3B transcriptionally upregulated in cells grown on gamma-Glu-met%3B mutation confers resistance to ethionine sulfoxide',
#         'experiment': 'EXISTENCE:direct assay:GO:0005886 plasma membrane [PMID:40288644],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:genetic interaction:GO:0042938 dipeptide transport [PMID:40288644],EXISTENCE:genetic interaction:GO:0071916 dipeptide transmembrane transporter activity [PMID:40288644],EXISTENCE:mutant phenotype:GO:0055085 transmembrane transport [PMID:8893857]',
#         'gbkey': 'CDS',
#         'gene': 'SEO1',
#         'locus_tag': 'YAL067C',
#         'product': 'putative permease SEO1',
#         'protein_id': 'NP_009333.1'},
#        'parent_gene_id': 'gene_rna-NM_001178208.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009333.1',
#          'chrom': 'NC_001133.9',
#          'start': 7235,
#          'end': 9016,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009333.1',
#           'Parent': 'rna-NM_001178208.1',
#           'Dbxref': 'SGD:S000000062,GeneID:851230,GenBank:NP_009333.1',
#           'Name': 'NP_009333.1',
#           'Note': 'High affinity dipeptide transmembrane transporter%3B involved in the transport of the gamma-Glu-met dipeptide across the plasma membrane%3B member of the allantoate transporter subfamily of the major facilitator superfamily%3B transcriptionally upregulated in cells grown on gamma-Glu-met%3B mutation confers resistance to ethionine sulfoxide',
#           'experiment': 'EXISTENCE:direct assay:GO:0005886 plasma membrane [PMID:40288644],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:genetic interaction:GO:0042938 dipeptide transport [PMID:40288644],EXISTENCE:genetic interaction:GO:0071916 dipeptide transmembrane transporter activity [PMID:40288644],EXISTENCE:mutant phenotype:GO:0055085 transmembrane transport [PMID:8893857]',
#           'gbkey': 'CDS',
#           'gene': 'SEO1',
#           'locus_tag': 'YAL067C',
#           'product': 'putative permease SEO1',
#           'protein_id': 'NP_009333.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009333.1',
#          'chrom': 'NC_001133.9',
#          'start': 7235,
#          'end': 9016,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009333.1',
#           'Parent': 'rna-NM_001178208.1',
#           'Dbxref': 'SGD:S000000062,GeneID:851230,GenBank:NP_009333.1',
#           'Name': 'NP_009333.1',
#           'Note': 'High affinity dipeptide transmembrane transporter%3B involved in the transport of the gamma-Glu-met dipeptide across the plasma membrane%3B member of the allantoate transporter subfamily of the major facilitator superfamily%3B transcriptionally upregulated in cells grown on gamma-Glu-met%3B mutation confers resistance to ethionine sulfoxide',
#           'experiment': 'EXISTENCE:direct assay:GO:0005886 plasma membrane [PMID:40288644],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:genetic interaction:GO:0042938 dipeptide transport [PMID:40288644],EXISTENCE:genetic interaction:GO:0071916 dipeptide transmembrane transporter activity [PMID:40288644],EXISTENCE:mutant phenotype:GO:0055085 transmembrane transport [PMID:8893857]',
#           'gbkey': 'CDS',
#           'gene': 'SEO1',
#           'locus_tag': 'YAL067C',
#           'product': 'putative permease SEO1',
#           'protein_id': 'NP_009333.1'}}]}]},
#     'gene_rna-NM_001179897.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001179897.1',
#       'chrom': 'NC_001133.9',
#       'start': 11565,
#       'end': 11951,
#       'strand': '-',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009335.1',
#        'Parent': 'rna-NM_001179897.1',
#        'Dbxref': 'SGD:S000001817,GeneID:851232,GenBank:NP_009335.1',
#        'Name': 'NP_009335.1',
#        'Note': 'hypothetical protein%3B shows sequence similarity to FLO1 and other flocculins',
#        'gbkey': 'CDS',
#        'locus_tag': 'YAL065C',
#        'product': 'uncharacterized protein',
#        'protein_id': 'NP_009335.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001179897.1',
#        'chrom': 'NC_001133.9',
#        'start': 11565,
#        'end': 11951,
#        'strand': '-',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009335.1',
#         'Parent': 'rna-NM_001179897.1',
#         'Dbxref': 'SGD:S000001817,GeneID:851232,GenBank:NP_009335.1',
#         'Name': 'NP_009335.1',
#         'Note': 'hypothetical protein%3B shows sequence similarity to FLO1 and other flocculins',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAL065C',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009335.1'},
#        'parent_gene_id': 'gene_rna-NM_001179897.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009335.1',
#          'chrom': 'NC_001133.9',
#          'start': 11565,
#          'end': 11951,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009335.1',
#           'Parent': 'rna-NM_001179897.1',
#           'Dbxref': 'SGD:S000001817,GeneID:851232,GenBank:NP_009335.1',
#           'Name': 'NP_009335.1',
#           'Note': 'hypothetical protein%3B shows sequence similarity to FLO1 and other flocculins',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL065C',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_009335.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009335.1',
#          'chrom': 'NC_001133.9',
#          'start': 11565,
#          'end': 11951,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009335.1',
#           'Parent': 'rna-NM_001179897.1',
#           'Dbxref': 'SGD:S000001817,GeneID:851232,GenBank:NP_009335.1',
#           'Name': 'NP_009335.1',
#           'Note': 'hypothetical protein%3B shows sequence similarity to FLO1 and other flocculins',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL065C',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_009335.1'}}]}]},
#     'gene_rna-NM_001180042.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001180042.1',
#       'chrom': 'NC_001133.9',
#       'start': 12046,
#       'end': 12426,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009336.1',
#        'Parent': 'rna-NM_001180042.1',
#        'Dbxref': 'SGD:S000002141,GeneID:851233,GenBank:NP_009336.1',
#        'Name': 'NP_009336.1',
#        'Note': 'Fungal-specific hypothetical protein',
#        'experiment': 'EXISTENCE:direct assay:GO:0005783 endoplasmic reticulum [PMID:26928762]',
#        'gbkey': 'CDS',
#        'locus_tag': 'YAL064W-B',
#        'product': 'uncharacterized protein',
#        'protein_id': 'NP_009336.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001180042.1',
#        'chrom': 'NC_001133.9',
#        'start': 12046,
#        'end': 12426,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009336.1',
#         'Parent': 'rna-NM_001180042.1',
#         'Dbxref': 'SGD:S000002141,GeneID:851233,GenBank:NP_009336.1',
#         'Name': 'NP_009336.1',
#         'Note': 'Fungal-specific hypothetical protein',
#         'experiment': 'EXISTENCE:direct assay:GO:0005783 endoplasmic reticulum [PMID:26928762]',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAL064W-B',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009336.1'},
#        'parent_gene_id': 'gene_rna-NM_001180042.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009336.1',
#          'chrom': 'NC_001133.9',
#          'start': 12046,
#          'end': 12426,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009336.1',
#           'Parent': 'rna-NM_001180042.1',
#           'Dbxref': 'SGD:S000002141,GeneID:851233,GenBank:NP_009336.1',
#           'Name': 'NP_009336.1',
#           'Note': 'Fungal-specific hypothetical protein',
#           'experiment': 'EXISTENCE:direct assay:GO:0005783 endoplasmic reticulum [PMID:26928762]',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL064W-B',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_009336.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009336.1',
#          'chrom': 'NC_001133.9',
#          'start': 12046,
#          'end': 12426,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009336.1',
#           'Parent': 'rna-NM_001180042.1',
#           'Dbxref': 'SGD:S000002141,GeneID:851233,GenBank:NP_009336.1',
#           'Name': 'NP_009336.1',
#           'Note': 'Fungal-specific hypothetical protein',
#           'experiment': 'EXISTENCE:direct assay:GO:0005783 endoplasmic reticulum [PMID:26928762]',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL064W-B',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_009336.1'}}]}]},
#     'gene_rna-NM_001180041.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001180041.1',
#       'chrom': 'NC_001133.9',
#       'start': 13363,
#       'end': 13743,
#       'strand': '-',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_058136.1',
#        'Parent': 'rna-NM_001180041.1',
#        'Dbxref': 'SGD:S000002140,GeneID:851234,GenBank:NP_058136.1',
#        'Name': 'NP_058136.1',
#        'Note': 'hypothetical protein%3B null mutant is sensitive to expression of the top1-T722A allele%3B not an essential gene',
#        'gbkey': 'CDS',
#        'gene': 'TDA8',
#        'locus_tag': 'YAL064C-A',
#        'product': 'Tda8p',
#        'protein_id': 'NP_058136.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001180041.1',
#        'chrom': 'NC_001133.9',
#        'start': 13363,
#        'end': 13743,
#        'strand': '-',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_058136.1',
#         'Parent': 'rna-NM_001180041.1',
#         'Dbxref': 'SGD:S000002140,GeneID:851234,GenBank:NP_058136.1',
#         'Name': 'NP_058136.1',
#         'Note': 'hypothetical protein%3B null mutant is sensitive to expression of the top1-T722A allele%3B not an essential gene',
#         'gbkey': 'CDS',
#         'gene': 'TDA8',
#         'locus_tag': 'YAL064C-A',
#         'product': 'Tda8p',
#         'protein_id': 'NP_058136.1'},
#        'parent_gene_id': 'gene_rna-NM_001180041.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_058136.1',
#          'chrom': 'NC_001133.9',
#          'start': 13363,
#          'end': 13743,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_058136.1',
#           'Parent': 'rna-NM_001180041.1',
#           'Dbxref': 'SGD:S000002140,GeneID:851234,GenBank:NP_058136.1',
#           'Name': 'NP_058136.1',
#           'Note': 'hypothetical protein%3B null mutant is sensitive to expression of the top1-T722A allele%3B not an essential gene',
#           'gbkey': 'CDS',
#           'gene': 'TDA8',
#           'locus_tag': 'YAL064C-A',
#           'product': 'Tda8p',
#           'protein_id': 'NP_058136.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_058136.1',
#          'chrom': 'NC_001133.9',
#          'start': 13363,
#          'end': 13743,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_058136.1',
#           'Parent': 'rna-NM_001180041.1',
#           'Dbxref': 'SGD:S000002140,GeneID:851234,GenBank:NP_058136.1',
#           'Name': 'NP_058136.1',
#           'Note': 'hypothetical protein%3B null mutant is sensitive to expression of the top1-T722A allele%3B not an essential gene',
#           'gbkey': 'CDS',
#           'gene': 'TDA8',
#           'locus_tag': 'YAL064C-A',
#           'product': 'Tda8p',
#           'protein_id': 'NP_058136.1'}}]}]},
#     'gene_rna-NM_001178206.2': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178206.2',
#       'chrom': 'NC_001133.9',
#       'start': 21566,
#       'end': 21850,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009337.2',
#        'Parent': 'rna-NM_001178206.2',
#        'Dbxref': 'SGD:S000000060,GeneID:851235,GenBank:NP_009337.2',
#        'Name': 'NP_009337.2',
#        'Note': 'hypothetical protein%3B may interact with ribosomes%2C based on co-purification experiments',
#        'gbkey': 'CDS',
#        'locus_tag': 'YAL064W',
#        'product': 'uncharacterized protein',
#        'protein_id': 'NP_009337.2'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178206.2',
#        'chrom': 'NC_001133.9',
#        'start': 21566,
#        'end': 21850,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009337.2',
#         'Parent': 'rna-NM_001178206.2',
#         'Dbxref': 'SGD:S000000060,GeneID:851235,GenBank:NP_009337.2',
#         'Name': 'NP_009337.2',
#         'Note': 'hypothetical protein%3B may interact with ribosomes%2C based on co-purification experiments',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAL064W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009337.2'},
#        'parent_gene_id': 'gene_rna-NM_001178206.2',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009337.2',
#          'chrom': 'NC_001133.9',
#          'start': 21566,
#          'end': 21850,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009337.2',
#           'Parent': 'rna-NM_001178206.2',
#           'Dbxref': 'SGD:S000000060,GeneID:851235,GenBank:NP_009337.2',
#           'Name': 'NP_009337.2',
#           'Note': 'hypothetical protein%3B may interact with ribosomes%2C based on co-purification experiments',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL064W',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_009337.2'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009337.2',
#          'chrom': 'NC_001133.9',
#          'start': 21566,
#          'end': 21850,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009337.2',
#           'Parent': 'rna-NM_001178206.2',
#           'Dbxref': 'SGD:S000000060,GeneID:851235,GenBank:NP_009337.2',
#           'Name': 'NP_009337.2',
#           'Note': 'hypothetical protein%3B may interact with ribosomes%2C based on co-purification experiments',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL064W',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_009337.2'}}]}]},
#     'gene_rna-NM_001184642.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001184642.1',
#       'chrom': 'NC_001133.9',
#       'start': 22395,
#       'end': 22685,
#       'strand': '-',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_878039.1',
#        'Parent': 'rna-NM_001184642.1',
#        'Dbxref': 'SGD:S000028813,GeneID:1466427,GenBank:NP_878039.1',
#        'Name': 'NP_878039.1',
#        'Note': 'hypothetical protein%3B identified by expression profiling and mass spectrometry',
#        'gbkey': 'CDS',
#        'locus_tag': 'YAL063C-A',
#        'product': 'uncharacterized protein',
#        'protein_id': 'NP_878039.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001184642.1',
#        'chrom': 'NC_001133.9',
#        'start': 22395,
#        'end': 22685,
#        'strand': '-',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_878039.1',
#         'Parent': 'rna-NM_001184642.1',
#         'Dbxref': 'SGD:S000028813,GeneID:1466427,GenBank:NP_878039.1',
#         'Name': 'NP_878039.1',
#         'Note': 'hypothetical protein%3B identified by expression profiling and mass spectrometry',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAL063C-A',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_878039.1'},
#        'parent_gene_id': 'gene_rna-NM_001184642.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_878039.1',
#          'chrom': 'NC_001133.9',
#          'start': 22395,
#          'end': 22685,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_878039.1',
#           'Parent': 'rna-NM_001184642.1',
#           'Dbxref': 'SGD:S000028813,GeneID:1466427,GenBank:NP_878039.1',
#           'Name': 'NP_878039.1',
#           'Note': 'hypothetical protein%3B identified by expression profiling and mass spectrometry',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL063C-A',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_878039.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_878039.1',
#          'chrom': 'NC_001133.9',
#          'start': 22395,
#          'end': 22685,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_878039.1',
#           'Parent': 'rna-NM_001184642.1',
#           'Dbxref': 'SGD:S000028813,GeneID:1466427,GenBank:NP_878039.1',
#           'Name': 'NP_878039.1',
#           'Note': 'hypothetical protein%3B identified by expression profiling and mass spectrometry',
#           'gbkey': 'CDS',
#           'locus_tag': 'YAL063C-A',
#           'product': 'uncharacterized protein',
#           'protein_id': 'NP_878039.1'}}]}]},
#     'gene_rna-NM_001178205.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178205.1',
#       'chrom': 'NC_001133.9',
#       'start': 24000,
#       'end': 27968,
#       'strand': '-',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009338.1',
#        'Parent': 'rna-NM_001178205.1',
#        'Dbxref': 'SGD:S000000059,GeneID:851236,GenBank:NP_009338.1',
#        'Name': 'NP_009338.1',
#        'Note': 'Lectin-like protein with similarity to Flo1p%3B thought to be expressed and involved in flocculation',
#        'experiment': 'EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:19087208],EXISTENCE:mutant phenotype:GO:0031589 cell-substrate adhesion [PMID:19087208]',
#        'gbkey': 'CDS',
#        'gene': 'FLO9',
#        'locus_tag': 'YAL063C',
#        'product': 'flocculin FLO9',
#        'protein_id': 'NP_009338.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178205.1',
#        'chrom': 'NC_001133.9',
#        'start': 24000,
#        'end': 27968,
#        'strand': '-',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009338.1',
#         'Parent': 'rna-NM_001178205.1',
#         'Dbxref': 'SGD:S000000059,GeneID:851236,GenBank:NP_009338.1',
#         'Name': 'NP_009338.1',
#         'Note': 'Lectin-like protein with similarity to Flo1p%3B thought to be expressed and involved in flocculation',
#         'experiment': 'EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:19087208],EXISTENCE:mutant phenotype:GO:0031589 cell-substrate adhesion [PMID:19087208]',
#         'gbkey': 'CDS',
#         'gene': 'FLO9',
#         'locus_tag': 'YAL063C',
#         'product': 'flocculin FLO9',
#         'protein_id': 'NP_009338.1'},
#        'parent_gene_id': 'gene_rna-NM_001178205.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009338.1',
#          'chrom': 'NC_001133.9',
#          'start': 24000,
#          'end': 27968,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009338.1',
#           'Parent': 'rna-NM_001178205.1',
#           'Dbxref': 'SGD:S000000059,GeneID:851236,GenBank:NP_009338.1',
#           'Name': 'NP_009338.1',
#           'Note': 'Lectin-like protein with similarity to Flo1p%3B thought to be expressed and involved in flocculation',
#           'experiment': 'EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:19087208],EXISTENCE:mutant phenotype:GO:0031589 cell-substrate adhesion [PMID:19087208]',
#           'gbkey': 'CDS',
#           'gene': 'FLO9',
#           'locus_tag': 'YAL063C',
#           'product': 'flocculin FLO9',
#           'protein_id': 'NP_009338.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009338.1',
#          'chrom': 'NC_001133.9',
#          'start': 24000,
#          'end': 27968,
#          'strand': '-',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009338.1',
#           'Parent': 'rna-NM_001178205.1',
#           'Dbxref': 'SGD:S000000059,GeneID:851236,GenBank:NP_009338.1',
#           'Name': 'NP_009338.1',
#           'Note': 'Lectin-like protein with similarity to Flo1p%3B thought to be expressed and involved in flocculation',
#           'experiment': 'EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:19087208],EXISTENCE:mutant phenotype:GO:0031589 cell-substrate adhesion [PMID:19087208]',
#           'gbkey': 'CDS',
#           'gene': 'FLO9',
#           'locus_tag': 'YAL063C',
#           'product': 'flocculin FLO9',
#           'protein_id': 'NP_009338.1'}}]}]},
#     'gene_rna-NM_001178204.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178204.1',
#       'chrom': 'NC_001133.9',
#       'start': 31567,
#       'end': 32940,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009339.1',
#        'Parent': 'rna-NM_001178204.1',
#        'Dbxref': 'SGD:S000000058,GeneID:851237,GenBank:NP_009339.1',
#        'Name': 'NP_009339.1',
#        'Note': 'NADP(+)-dependent glutamate dehydrogenase%3B synthesizes glutamate from ammonia and alpha-ketoglutarate%3B rate of alpha-ketoglutarate utilization differs from Gdh1p%3B expression regulated by nitrogen and carbon sources%3B GDH3 has a paralog%2C GDH1%2C that arose from the whole genome duplication',
#        'experiment': 'EXISTENCE:direct assay:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:11562373],EXISTENCE:direct assay:GO:0005634 nucleus [PMID:4126],EXISTENCE:direct assay:GO:0005739 mitochondrion [PMID:14576278|PMID:16823961],EXISTENCE:mutant phenotype:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:9287019],EXISTENCE:mutant phenotype:GO:0006537 glutamate biosynthetic process [PMID:9287019]',
#        'gbkey': 'CDS',
#        'gene': 'GDH3',
#        'locus_tag': 'YAL062W',
#        'product': 'glutamate dehydrogenase (NADP(+)) GDH3',
#        'protein_id': 'NP_009339.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178204.1',
#        'chrom': 'NC_001133.9',
#        'start': 31567,
#        'end': 32940,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009339.1',
#         'Parent': 'rna-NM_001178204.1',
#         'Dbxref': 'SGD:S000000058,GeneID:851237,GenBank:NP_009339.1',
#         'Name': 'NP_009339.1',
#         'Note': 'NADP(+)-dependent glutamate dehydrogenase%3B synthesizes glutamate from ammonia and alpha-ketoglutarate%3B rate of alpha-ketoglutarate utilization differs from Gdh1p%3B expression regulated by nitrogen and carbon sources%3B GDH3 has a paralog%2C GDH1%2C that arose from the whole genome duplication',
#         'experiment': 'EXISTENCE:direct assay:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:11562373],EXISTENCE:direct assay:GO:0005634 nucleus [PMID:4126],EXISTENCE:direct assay:GO:0005739 mitochondrion [PMID:14576278|PMID:16823961],EXISTENCE:mutant phenotype:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:9287019],EXISTENCE:mutant phenotype:GO:0006537 glutamate biosynthetic process [PMID:9287019]',
#         'gbkey': 'CDS',
#         'gene': 'GDH3',
#         'locus_tag': 'YAL062W',
#         'product': 'glutamate dehydrogenase (NADP(+)) GDH3',
#         'protein_id': 'NP_009339.1'},
#        'parent_gene_id': 'gene_rna-NM_001178204.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009339.1',
#          'chrom': 'NC_001133.9',
#          'start': 31567,
#          'end': 32940,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009339.1',
#           'Parent': 'rna-NM_001178204.1',
#           'Dbxref': 'SGD:S000000058,GeneID:851237,GenBank:NP_009339.1',
#           'Name': 'NP_009339.1',
#           'Note': 'NADP(+)-dependent glutamate dehydrogenase%3B synthesizes glutamate from ammonia and alpha-ketoglutarate%3B rate of alpha-ketoglutarate utilization differs from Gdh1p%3B expression regulated by nitrogen and carbon sources%3B GDH3 has a paralog%2C GDH1%2C that arose from the whole genome duplication',
#           'experiment': 'EXISTENCE:direct assay:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:11562373],EXISTENCE:direct assay:GO:0005634 nucleus [PMID:4126],EXISTENCE:direct assay:GO:0005739 mitochondrion [PMID:14576278|PMID:16823961],EXISTENCE:mutant phenotype:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:9287019],EXISTENCE:mutant phenotype:GO:0006537 glutamate biosynthetic process [PMID:9287019]',
#           'gbkey': 'CDS',
#           'gene': 'GDH3',
#           'locus_tag': 'YAL062W',
#           'product': 'glutamate dehydrogenase (NADP(+)) GDH3',
#           'protein_id': 'NP_009339.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009339.1',
#          'chrom': 'NC_001133.9',
#          'start': 31567,
#          'end': 32940,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009339.1',
#           'Parent': 'rna-NM_001178204.1',
#           'Dbxref': 'SGD:S000000058,GeneID:851237,GenBank:NP_009339.1',
#           'Name': 'NP_009339.1',
#           'Note': 'NADP(+)-dependent glutamate dehydrogenase%3B synthesizes glutamate from ammonia and alpha-ketoglutarate%3B rate of alpha-ketoglutarate utilization differs from Gdh1p%3B expression regulated by nitrogen and carbon sources%3B GDH3 has a paralog%2C GDH1%2C that arose from the whole genome duplication',
#           'experiment': 'EXISTENCE:direct assay:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:11562373],EXISTENCE:direct assay:GO:0005634 nucleus [PMID:4126],EXISTENCE:direct assay:GO:0005739 mitochondrion [PMID:14576278|PMID:16823961],EXISTENCE:mutant phenotype:GO:0004354 glutamate dehydrogenase (NADP+) activity [PMID:9287019],EXISTENCE:mutant phenotype:GO:0006537 glutamate biosynthetic process [PMID:9287019]',
#           'gbkey': 'CDS',
#           'gene': 'GDH3',
#           'locus_tag': 'YAL062W',
#           'product': 'glutamate dehydrogenase (NADP(+)) GDH3',
#           'protein_id': 'NP_009339.1'}}]}]},
#     'gene_rna-NM_001178203.1': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178203.1',
#       'chrom': 'NC_001133.9',
#       'start': 33448,
#       'end': 34701,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009340.1',
#        'Parent': 'rna-NM_001178203.1',
#        'Dbxref': 'SGD:S000000057,GeneID:851238,GenBank:NP_009340.1',
#        'Name': 'NP_009340.1',
#        'Note': 'Putative medium-chain alcohol dehydrogenase with similarity to BDH1%3B transcription induced by constitutively active PDR1 and PDR3',
#        'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095]',
#        'gbkey': 'CDS',
#        'gene': 'BDH2',
#        'locus_tag': 'YAL061W',
#        'product': 'putative dehydrogenase BDH2',
#        'protein_id': 'NP_009340.1'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178203.1',
#        'chrom': 'NC_001133.9',
#        'start': 33448,
#        'end': 34701,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009340.1',
#         'Parent': 'rna-NM_001178203.1',
#         'Dbxref': 'SGD:S000000057,GeneID:851238,GenBank:NP_009340.1',
#         'Name': 'NP_009340.1',
#         'Note': 'Putative medium-chain alcohol dehydrogenase with similarity to BDH1%3B transcription induced by constitutively active PDR1 and PDR3',
#         'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095]',
#         'gbkey': 'CDS',
#         'gene': 'BDH2',
#         'locus_tag': 'YAL061W',
#         'product': 'putative dehydrogenase BDH2',
#         'protein_id': 'NP_009340.1'},
#        'parent_gene_id': 'gene_rna-NM_001178203.1',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009340.1',
#          'chrom': 'NC_001133.9',
#          'start': 33448,
#          'end': 34701,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009340.1',
#           'Parent': 'rna-NM_001178203.1',
#           'Dbxref': 'SGD:S000000057,GeneID:851238,GenBank:NP_009340.1',
#           'Name': 'NP_009340.1',
#           'Note': 'Putative medium-chain alcohol dehydrogenase with similarity to BDH1%3B transcription induced by constitutively active PDR1 and PDR3',
#           'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095]',
#           'gbkey': 'CDS',
#           'gene': 'BDH2',
#           'locus_tag': 'YAL061W',
#           'product': 'putative dehydrogenase BDH2',
#           'protein_id': 'NP_009340.1'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009340.1',
#          'chrom': 'NC_001133.9',
#          'start': 33448,
#          'end': 34701,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009340.1',
#           'Parent': 'rna-NM_001178203.1',
#           'Dbxref': 'SGD:S000000057,GeneID:851238,GenBank:NP_009340.1',
#           'Name': 'NP_009340.1',
#           'Note': 'Putative medium-chain alcohol dehydrogenase with similarity to BDH1%3B transcription induced by constitutively active PDR1 and PDR3',
#           'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095]',
#           'gbkey': 'CDS',
#           'gene': 'BDH2',
#           'locus_tag': 'YAL061W',
#           'product': 'putative dehydrogenase BDH2',
#           'protein_id': 'NP_009340.1'}}]}]},
#     'gene_rna-NM_001178202.2': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178202.2',
#       'chrom': 'NC_001133.9',
#       'start': 35155,
#       'end': 36303,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009341.2',
#        'Parent': 'rna-NM_001178202.2',
#        'Dbxref': 'SGD:S000000056,GeneID:851239,GenBank:NP_009341.2',
#        'Name': 'NP_009341.2',
#        'Note': 'NAD-dependent (R%2CR)-butanediol dehydrogenase%3B catalyzes oxidation of (R%2CR)-2%2C3-butanediol to (3R)-acetoin%2C oxidation of meso-butanediol to (3S)-acetoin%2C and reduction of acetoin%3B enhances use of 2%2C3-butanediol as an aerobic carbon source',
#        'experiment': 'EXISTENCE:direct assay:GO:0000721 (R%2CR)-butanediol dehydrogenase activity [PMID:10938079],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095|PMID:11914276],EXISTENCE:mutant phenotype:GO:0006066 alcohol metabolic process [PMID:10938079],EXISTENCE:mutant phenotype:GO:0034079 butanediol biosynthetic process [PMID:19966022]',
#        'gbkey': 'CDS',
#        'gene': 'BDH1',
#        'locus_tag': 'YAL060W',
#        'product': '(R%2CR)-butanediol dehydrogenase',
#        'protein_id': 'NP_009341.2'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178202.2',
#        'chrom': 'NC_001133.9',
#        'start': 35155,
#        'end': 36303,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009341.2',
#         'Parent': 'rna-NM_001178202.2',
#         'Dbxref': 'SGD:S000000056,GeneID:851239,GenBank:NP_009341.2',
#         'Name': 'NP_009341.2',
#         'Note': 'NAD-dependent (R%2CR)-butanediol dehydrogenase%3B catalyzes oxidation of (R%2CR)-2%2C3-butanediol to (3R)-acetoin%2C oxidation of meso-butanediol to (3S)-acetoin%2C and reduction of acetoin%3B enhances use of 2%2C3-butanediol as an aerobic carbon source',
#         'experiment': 'EXISTENCE:direct assay:GO:0000721 (R%2CR)-butanediol dehydrogenase activity [PMID:10938079],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095|PMID:11914276],EXISTENCE:mutant phenotype:GO:0006066 alcohol metabolic process [PMID:10938079],EXISTENCE:mutant phenotype:GO:0034079 butanediol biosynthetic process [PMID:19966022]',
#         'gbkey': 'CDS',
#         'gene': 'BDH1',
#         'locus_tag': 'YAL060W',
#         'product': '(R%2CR)-butanediol dehydrogenase',
#         'protein_id': 'NP_009341.2'},
#        'parent_gene_id': 'gene_rna-NM_001178202.2',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009341.2',
#          'chrom': 'NC_001133.9',
#          'start': 35155,
#          'end': 36303,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009341.2',
#           'Parent': 'rna-NM_001178202.2',
#           'Dbxref': 'SGD:S000000056,GeneID:851239,GenBank:NP_009341.2',
#           'Name': 'NP_009341.2',
#           'Note': 'NAD-dependent (R%2CR)-butanediol dehydrogenase%3B catalyzes oxidation of (R%2CR)-2%2C3-butanediol to (3R)-acetoin%2C oxidation of meso-butanediol to (3S)-acetoin%2C and reduction of acetoin%3B enhances use of 2%2C3-butanediol as an aerobic carbon source',
#           'experiment': 'EXISTENCE:direct assay:GO:0000721 (R%2CR)-butanediol dehydrogenase activity [PMID:10938079],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095|PMID:11914276],EXISTENCE:mutant phenotype:GO:0006066 alcohol metabolic process [PMID:10938079],EXISTENCE:mutant phenotype:GO:0034079 butanediol biosynthetic process [PMID:19966022]',
#           'gbkey': 'CDS',
#           'gene': 'BDH1',
#           'locus_tag': 'YAL060W',
#           'product': '(R%2CR)-butanediol dehydrogenase',
#           'protein_id': 'NP_009341.2'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009341.2',
#          'chrom': 'NC_001133.9',
#          'start': 35155,
#          'end': 36303,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009341.2',
#           'Parent': 'rna-NM_001178202.2',
#           'Dbxref': 'SGD:S000000056,GeneID:851239,GenBank:NP_009341.2',
#           'Name': 'NP_009341.2',
#           'Note': 'NAD-dependent (R%2CR)-butanediol dehydrogenase%3B catalyzes oxidation of (R%2CR)-2%2C3-butanediol to (3R)-acetoin%2C oxidation of meso-butanediol to (3S)-acetoin%2C and reduction of acetoin%3B enhances use of 2%2C3-butanediol as an aerobic carbon source',
#           'experiment': 'EXISTENCE:direct assay:GO:0000721 (R%2CR)-butanediol dehydrogenase activity [PMID:10938079],EXISTENCE:direct assay:GO:0005737 cytoplasm [PMID:14562095|PMID:11914276],EXISTENCE:mutant phenotype:GO:0006066 alcohol metabolic process [PMID:10938079],EXISTENCE:mutant phenotype:GO:0034079 butanediol biosynthetic process [PMID:19966022]',
#           'gbkey': 'CDS',
#           'gene': 'BDH1',
#           'locus_tag': 'YAL060W',
#           'product': '(R%2CR)-butanediol dehydrogenase',
#           'protein_id': 'NP_009341.2'}}]}]},
#     'gene_rna-NM_001178201.2': {'gene': {'type': 'gene',
#       'id': 'gene_rna-NM_001178201.2',
#       'chrom': 'NC_001133.9',
#       'start': 36509,
#       'end': 37147,
#       'strand': '+',
#       'score': None,
#       'phase': 0,
#       'attributes': {'ID': 'cds-NP_009342.2',
#        'Parent': 'rna-NM_001178201.2',
#        'Dbxref': 'SGD:S000000055,GeneID:851240,GenBank:NP_009342.2',
#        'Name': 'NP_009342.2',
#        'Note': 'Pre-ribosomal factor involved in 60S ribosomal protein subunit export%3B associates with the pre-60S particle%3B shuttles between the nucleus and cytoplasm',
#        'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095|PMID:11583615],EXISTENCE:direct assay:GO:0005730 nucleolus [PMID:11583615],EXISTENCE:direct assay:GO:0030687 preribosome%2C large subunit precursor [PMID:20348449],EXISTENCE:direct assay:GO:1990275 preribosome binding [PMID:35139378],EXISTENCE:genetic interaction:GO:0000055 ribosomal large subunit export from nucleus [PMID:20348449|PMID:11583615]',
#        'gbkey': 'CDS',
#        'gene': 'ECM1',
#        'locus_tag': 'YAL059W',
#        'product': 'Ecm1p',
#        'protein_id': 'NP_009342.2'},
#       'gene_biotype': None,
#       'pseudo': False},
#      'transcripts': [{'type': 'mRNA',
#        'id': 'rna-NM_001178201.2',
#        'chrom': 'NC_001133.9',
#        'start': 36509,
#        'end': 37147,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009342.2',
#         'Parent': 'rna-NM_001178201.2',
#         'Dbxref': 'SGD:S000000055,GeneID:851240,GenBank:NP_009342.2',
#         'Name': 'NP_009342.2',
#         'Note': 'Pre-ribosomal factor involved in 60S ribosomal protein subunit export%3B associates with the pre-60S particle%3B shuttles between the nucleus and cytoplasm',
#         'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095|PMID:11583615],EXISTENCE:direct assay:GO:0005730 nucleolus [PMID:11583615],EXISTENCE:direct assay:GO:0030687 preribosome%2C large subunit precursor [PMID:20348449],EXISTENCE:direct assay:GO:1990275 preribosome binding [PMID:35139378],EXISTENCE:genetic interaction:GO:0000055 ribosomal large subunit export from nucleus [PMID:20348449|PMID:11583615]',
#         'gbkey': 'CDS',
#         'gene': 'ECM1',
#         'locus_tag': 'YAL059W',
#         'product': 'Ecm1p',
#         'protein_id': 'NP_009342.2'},
#        'parent_gene_id': 'gene_rna-NM_001178201.2',
#        'exons': [{'type': 'exon',
#          'id': 'cds-NP_009342.2',
#          'chrom': 'NC_001133.9',
#          'start': 36509,
#          'end': 37147,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009342.2',
#           'Parent': 'rna-NM_001178201.2',
#           'Dbxref': 'SGD:S000000055,GeneID:851240,GenBank:NP_009342.2',
#           'Name': 'NP_009342.2',
#           'Note': 'Pre-ribosomal factor involved in 60S ribosomal protein subunit export%3B associates with the pre-60S particle%3B shuttles between the nucleus and cytoplasm',
#           'experiment': 'EXISTENCE:direct assay:GO:0005634 nucleus [PMID:14562095|PMID:11583615],EXISTENCE:direct assay:GO:0005730 nucleolus [PMID:11583615],EXISTENCE:direct assay:GO:0030687 preribosome%2C large subunit precursor [PMID:20348449],EXISTENCE:direct assay:GO:1990275 preribosome binding [PMID:35139378],EXISTENCE:genetic interaction:GO:0000055 ribosomal large subunit export from nucleus [PMID:20348449|PMID:11583615]',
#           'gbkey': 'CDS',
#           'gene': 'ECM1',
#           'locus_tag': 'YAL059W',
#           'product': 'Ecm1p',
#           'protein_id': 'NP_009342.2'}}],
#        'cds': [{'type': 'CDS',
#          'id': 'cds-NP_009342.2',
#          'chrom': 'NC_001133.9',
#          'start': 36509,
#          'end': 37147,
#          'strand': '+',
#          'score': None,
#          'phase': 0,
#          'attributes': {'ID': 'cds-NP_009342.2',
#           'Parent': 'rna-NM_001178201.2',
#           'Dbxref': 'SGD:S000000055,GeneID:851240,GenBank:NP_009342.2',
#           'Name': 'NP_009342.2',
#           'Note': 'Pre-ribosomal factor involved in 60S ribosomal protein subunit export%3B associates with the pre-60S particle%3B shuttles between the nucleus and cytoplasm',
# ...
#         'gbkey': 'CDS',
#         'gene': 'SWH1',
#         'locus_tag': 'YAR042W',
#         'product': 'oxysterol-binding protein related protein SWH1',
#         'protein_id': 'NP_009421.3'}}],
#      'cds': [{'type': 'CDS',
#        'id': 'cds-NP_009421.3',
#        'chrom': 'NC_001133.9',
#        'start': 192619,
#        'end': 196185,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009421.3',
#         'Parent': 'rna-NM_001178227.1',
#         'Dbxref': 'SGD:S000000081,GeneID:851286,GenBank:NP_009421.3',
#         'Name': 'NP_009421.3',
#         'Note': 'Protein similar to mammalian oxysterol-binding protein%3B contains ankyrin repeats and FFAT motif%3B interacts with ER anchor Scs2p at the nucleus-vacuole junction%3B regulated by sterol binding%3B SWH1 has a paralog%2C OSH2%2C that arose from the whole genome duplication',
#         'experiment': 'EXISTENCE:direct assay:GO:0000138 Golgi trans cisterna [PMID:11408574],EXISTENCE:direct assay:GO:0005635 nuclear envelope [PMID:12727870],EXISTENCE:direct assay:GO:0005769 early endosome [PMID:11408574],EXISTENCE:direct assay:GO:0005783 endoplasmic reticulum [PMID:12727870],EXISTENCE:direct assay:GO:0008289 lipid binding [PMID:20008566],EXISTENCE:direct assay:GO:0015918 sterol transport [PMID:20008566],EXISTENCE:direct assay:GO:0071561 nucleus-vacuole junction [PMID:25420878],EXISTENCE:direct assay:GO:0120015 sterol transfer activity [PMID:20008566],EXISTENCE:genetic interaction:GO:0006887 exocytosis [PMID:17004323],EXISTENCE:genetic interaction:GO:0006897 endocytosis [PMID:15173322],EXISTENCE:genetic interaction:GO:0015918 sterol transport [PMID:16585271],EXISTENCE:genetic interaction:GO:0030011 maintenance of cell polarity [PMID:17004323],EXISTENCE:genetic interaction:GO:0034727 piecemeal microautophagy of the nucleus [PMID:15367582]',
#         'gbkey': 'CDS',
#         'gene': 'SWH1',
#         'locus_tag': 'YAR042W',
#         'product': 'oxysterol-binding protein related protein SWH1',
#         'protein_id': 'NP_009421.3'}}]},
#     'rna-NM_001178230.1': {'type': 'mRNA',
#      'id': 'rna-NM_001178230.1',
#      'chrom': 'NC_001133.9',
#      'start': 203403,
#      'end': 208016,
#      'strand': '+',
#      'score': None,
#      'phase': 0,
#      'attributes': {'ID': 'cds-NP_009424.1',
#       'Parent': 'rna-NM_001178230.1',
#       'Dbxref': 'SGD:S000000084,GeneID:851289,GenBank:NP_009424.1',
#       'Name': 'NP_009424.1',
#       'Note': 'Lectin-like protein involved in flocculation%3B cell wall protein that binds mannose chains on the surface of other cells%2C confers floc-forming ability that is chymotrypsin sensitive and heat resistant%3B important for co-flocculation with other yeasts%2C mediating interaction with specific species%3B FLO1 has a paralog%2C FLO5%2C that arose from a segmental duplication',
#       'experiment': 'EXISTENCE:direct assay:GO:0009277 fungal-type cell wall [PMID:11956747|PMID:9483793],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:23383507|PMID:11027318|PMID:7483845|PMID:19013280],EXISTENCE:mutant phenotype:GO:0005537 D-mannose binding [PMID:9851992]',
#       'gbkey': 'CDS',
#       'gene': 'FLO1',
#       'locus_tag': 'YAR050W',
#       'product': 'flocculin FLO1',
#       'protein_id': 'NP_009424.1'},
#      'parent_gene_id': 'gene_rna-NM_001178230.1',
#      'exons': [{'type': 'exon',
#        'id': 'cds-NP_009424.1',
#        'chrom': 'NC_001133.9',
#        'start': 203403,
#        'end': 208016,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009424.1',
#         'Parent': 'rna-NM_001178230.1',
#         'Dbxref': 'SGD:S000000084,GeneID:851289,GenBank:NP_009424.1',
#         'Name': 'NP_009424.1',
#         'Note': 'Lectin-like protein involved in flocculation%3B cell wall protein that binds mannose chains on the surface of other cells%2C confers floc-forming ability that is chymotrypsin sensitive and heat resistant%3B important for co-flocculation with other yeasts%2C mediating interaction with specific species%3B FLO1 has a paralog%2C FLO5%2C that arose from a segmental duplication',
#         'experiment': 'EXISTENCE:direct assay:GO:0009277 fungal-type cell wall [PMID:11956747|PMID:9483793],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:23383507|PMID:11027318|PMID:7483845|PMID:19013280],EXISTENCE:mutant phenotype:GO:0005537 D-mannose binding [PMID:9851992]',
#         'gbkey': 'CDS',
#         'gene': 'FLO1',
#         'locus_tag': 'YAR050W',
#         'product': 'flocculin FLO1',
#         'protein_id': 'NP_009424.1'}}],
#      'cds': [{'type': 'CDS',
#        'id': 'cds-NP_009424.1',
#        'chrom': 'NC_001133.9',
#        'start': 203403,
#        'end': 208016,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009424.1',
#         'Parent': 'rna-NM_001178230.1',
#         'Dbxref': 'SGD:S000000084,GeneID:851289,GenBank:NP_009424.1',
#         'Name': 'NP_009424.1',
#         'Note': 'Lectin-like protein involved in flocculation%3B cell wall protein that binds mannose chains on the surface of other cells%2C confers floc-forming ability that is chymotrypsin sensitive and heat resistant%3B important for co-flocculation with other yeasts%2C mediating interaction with specific species%3B FLO1 has a paralog%2C FLO5%2C that arose from a segmental duplication',
#         'experiment': 'EXISTENCE:direct assay:GO:0009277 fungal-type cell wall [PMID:11956747|PMID:9483793],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762],EXISTENCE:mutant phenotype:GO:0000128 flocculation [PMID:19420680|PMID:23383507|PMID:11027318|PMID:7483845|PMID:19013280],EXISTENCE:mutant phenotype:GO:0005537 D-mannose binding [PMID:9851992]',
#         'gbkey': 'CDS',
#         'gene': 'FLO1',
#         'locus_tag': 'YAR050W',
#         'product': 'flocculin FLO1',
#         'protein_id': 'NP_009424.1'}}]},
#     'rna-NM_001178235.1': {'type': 'mRNA',
#      'id': 'rna-NM_001178235.1',
#      'chrom': 'NC_001133.9',
#      'start': 220198,
#      'end': 220497,
#      'strand': '+',
#      'score': None,
#      'phase': 0,
#      'attributes': {'ID': 'cds-NP_009429.1',
#       'Parent': 'rna-NM_001178235.1',
#       'Dbxref': 'SGD:S000000089,GeneID:851294,GenBank:NP_009429.1',
#       'Name': 'NP_009429.1',
#       'Note': 'Pseudogenic fragment with similarity to flocculins%3B YAR064W has a paralog%2C YHR213W-B%2C that arose from a segmental duplication',
#       'gbkey': 'CDS',
#       'locus_tag': 'YAR064W',
#       'product': 'uncharacterized protein',
#       'protein_id': 'NP_009429.1'},
#      'parent_gene_id': 'gene_rna-NM_001178235.1',
#      'exons': [{'type': 'exon',
#        'id': 'cds-NP_009429.1',
#        'chrom': 'NC_001133.9',
#        'start': 220198,
#        'end': 220497,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009429.1',
#         'Parent': 'rna-NM_001178235.1',
#         'Dbxref': 'SGD:S000000089,GeneID:851294,GenBank:NP_009429.1',
#         'Name': 'NP_009429.1',
#         'Note': 'Pseudogenic fragment with similarity to flocculins%3B YAR064W has a paralog%2C YHR213W-B%2C that arose from a segmental duplication',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAR064W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009429.1'}}],
#      'cds': [{'type': 'CDS',
#        'id': 'cds-NP_009429.1',
#        'chrom': 'NC_001133.9',
#        'start': 220198,
#        'end': 220497,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009429.1',
#         'Parent': 'rna-NM_001178235.1',
#         'Dbxref': 'SGD:S000000089,GeneID:851294,GenBank:NP_009429.1',
#         'Name': 'NP_009429.1',
#         'Note': 'Pseudogenic fragment with similarity to flocculins%3B YAR064W has a paralog%2C YHR213W-B%2C that arose from a segmental duplication',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAR064W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009429.1'}}]},
#     'rna-NM_001180045.1': {'type': 'mRNA',
#      'id': 'rna-NM_001180045.1',
#      'chrom': 'NC_001133.9',
#      'start': 221049,
#      'end': 221660,
#      'strand': '+',
#      'score': None,
#      'phase': 0,
#      'attributes': {'ID': 'cds-NP_009430.1',
#       'Parent': 'rna-NM_001180045.1',
#       'Dbxref': 'SGD:S000002144,GeneID:851295,GenBank:NP_009430.1',
#       'Name': 'NP_009430.1',
#       'Note': 'Putative GPI protein%3B SWAT-GFP and mCherry fusion proteins localize to the endoplasmic reticulum and vacuole respectively%3B YAR066W has a paralog%2C YHR214W%2C that arose from a segmental duplication',
#       'gbkey': 'CDS',
#       'locus_tag': 'YAR066W',
#       'product': 'uncharacterized protein',
#       'protein_id': 'NP_009430.1'},
#      'parent_gene_id': 'gene_rna-NM_001180045.1',
#      'exons': [{'type': 'exon',
#        'id': 'cds-NP_009430.1',
#        'chrom': 'NC_001133.9',
#        'start': 221049,
#        'end': 221660,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009430.1',
#         'Parent': 'rna-NM_001180045.1',
#         'Dbxref': 'SGD:S000002144,GeneID:851295,GenBank:NP_009430.1',
#         'Name': 'NP_009430.1',
#         'Note': 'Putative GPI protein%3B SWAT-GFP and mCherry fusion proteins localize to the endoplasmic reticulum and vacuole respectively%3B YAR066W has a paralog%2C YHR214W%2C that arose from a segmental duplication',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAR066W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009430.1'}}],
#      'cds': [{'type': 'CDS',
#        'id': 'cds-NP_009430.1',
#        'chrom': 'NC_001133.9',
#        'start': 221049,
#        'end': 221660,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009430.1',
#         'Parent': 'rna-NM_001180045.1',
#         'Dbxref': 'SGD:S000002144,GeneID:851295,GenBank:NP_009430.1',
#         'Name': 'NP_009430.1',
#         'Note': 'Putative GPI protein%3B SWAT-GFP and mCherry fusion proteins localize to the endoplasmic reticulum and vacuole respectively%3B YAR066W has a paralog%2C YHR214W%2C that arose from a segmental duplication',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAR066W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009430.1'}}]},
#     'rna-NM_001178236.1': {'type': 'mRNA',
#      'id': 'rna-NM_001178236.1',
#      'chrom': 'NC_001133.9',
#      'start': 222406,
#      'end': 222891,
#      'strand': '+',
#      'score': None,
#      'phase': 0,
#      'attributes': {'ID': 'cds-NP_009431.1',
#       'Parent': 'rna-NM_001178236.1',
#       'Dbxref': 'SGD:S000000091,GeneID:851296,GenBank:NP_009431.1',
#       'Name': 'NP_009431.1',
#       'Note': 'Fungal-specific hypothetical protein%3B induced in respiratory-deficient cells%3B YAR068W has a paralog%2C YHR214W-A%2C that arose from a segmental duplication',
#       'gbkey': 'CDS',
#       'locus_tag': 'YAR068W',
#       'product': 'uncharacterized protein',
#       'protein_id': 'NP_009431.1'},
#      'parent_gene_id': 'gene_rna-NM_001178236.1',
#      'exons': [{'type': 'exon',
#        'id': 'cds-NP_009431.1',
#        'chrom': 'NC_001133.9',
#        'start': 222406,
#        'end': 222891,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009431.1',
#         'Parent': 'rna-NM_001178236.1',
#         'Dbxref': 'SGD:S000000091,GeneID:851296,GenBank:NP_009431.1',
#         'Name': 'NP_009431.1',
#         'Note': 'Fungal-specific hypothetical protein%3B induced in respiratory-deficient cells%3B YAR068W has a paralog%2C YHR214W-A%2C that arose from a segmental duplication',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAR068W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009431.1'}}],
#      'cds': [{'type': 'CDS',
#        'id': 'cds-NP_009431.1',
#        'chrom': 'NC_001133.9',
#        'start': 222406,
#        'end': 222891,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009431.1',
#         'Parent': 'rna-NM_001178236.1',
#         'Dbxref': 'SGD:S000000091,GeneID:851296,GenBank:NP_009431.1',
#         'Name': 'NP_009431.1',
#         'Note': 'Fungal-specific hypothetical protein%3B induced in respiratory-deficient cells%3B YAR068W has a paralog%2C YHR214W-A%2C that arose from a segmental duplication',
#         'gbkey': 'CDS',
#         'locus_tag': 'YAR068W',
#         'product': 'uncharacterized protein',
#         'protein_id': 'NP_009431.1'}}]},
#     'rna-NM_001178239.1': {'type': 'mRNA',
#      'id': 'rna-NM_001178239.1',
#      'chrom': 'NC_001133.9',
#      'start': 225460,
#      'end': 226863,
#      'strand': '+',
#      'score': None,
#      'phase': 0,
#      'attributes': {'ID': 'cds-NP_009434.1',
#       'Parent': 'rna-NM_001178239.1',
#       'Dbxref': 'SGD:S000000094,GeneID:851299,GenBank:NP_009434.1',
#       'Name': 'NP_009434.1',
#       'Note': 'One of three repressible acid phosphatases%3B glycoprotein that is transported to the cell surface by the secretory pathway%3B induced by phosphate starvation and coordinately regulated by PHO4 and PHO2%3B PHO11 has a paralog%2C PHO12%2C that arose from a segmental duplication',
#       'experiment': 'EXISTENCE:direct assay:GO:0003993 acid phosphatase activity [PMID:8817921],EXISTENCE:direct assay:GO:0005576 extracellular region [PMID:8817921],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762]',
#       'gbkey': 'CDS',
#       'gene': 'PHO11',
#       'locus_tag': 'YAR071W',
#       'product': 'acid phosphatase PHO11',
#       'protein_id': 'NP_009434.1'},
#      'parent_gene_id': 'gene_rna-NM_001178239.1',
#      'exons': [{'type': 'exon',
#        'id': 'cds-NP_009434.1',
#        'chrom': 'NC_001133.9',
#        'start': 225460,
#        'end': 226863,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009434.1',
#         'Parent': 'rna-NM_001178239.1',
#         'Dbxref': 'SGD:S000000094,GeneID:851299,GenBank:NP_009434.1',
#         'Name': 'NP_009434.1',
#         'Note': 'One of three repressible acid phosphatases%3B glycoprotein that is transported to the cell surface by the secretory pathway%3B induced by phosphate starvation and coordinately regulated by PHO4 and PHO2%3B PHO11 has a paralog%2C PHO12%2C that arose from a segmental duplication',
#         'experiment': 'EXISTENCE:direct assay:GO:0003993 acid phosphatase activity [PMID:8817921],EXISTENCE:direct assay:GO:0005576 extracellular region [PMID:8817921],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762]',
#         'gbkey': 'CDS',
#         'gene': 'PHO11',
#         'locus_tag': 'YAR071W',
#         'product': 'acid phosphatase PHO11',
#         'protein_id': 'NP_009434.1'}}],
#      'cds': [{'type': 'CDS',
#        'id': 'cds-NP_009434.1',
#        'chrom': 'NC_001133.9',
#        'start': 225460,
#        'end': 226863,
#        'strand': '+',
#        'score': None,
#        'phase': 0,
#        'attributes': {'ID': 'cds-NP_009434.1',
#         'Parent': 'rna-NM_001178239.1',
#         'Dbxref': 'SGD:S000000094,GeneID:851299,GenBank:NP_009434.1',
#         'Name': 'NP_009434.1',
#         'Note': 'One of three repressible acid phosphatases%3B glycoprotein that is transported to the cell surface by the secretory pathway%3B induced by phosphate starvation and coordinately regulated by PHO4 and PHO2%3B PHO11 has a paralog%2C PHO12%2C that arose from a segmental duplication',
#         'experiment': 'EXISTENCE:direct assay:GO:0003993 acid phosphatase activity [PMID:8817921],EXISTENCE:direct assay:GO:0005576 extracellular region [PMID:8817921],EXISTENCE:direct assay:GO:0071944 cell periphery [PMID:26928762]',
#         'gbkey': 'CDS',
#         'gene': 'PHO11',
#         'locus_tag': 'YAR071W',
#         'product': 'acid phosphatase PHO11',
#         'protein_id': 'NP_009434.1'}}]}}})]

# %%
tile
# Out:
# []

# %%
import sys

print(f"Python version: {sys.version}")
print(f"Version info: {sys.version_info}")
# Out:
# Python version: 3.10.15 | packaged by conda-forge | (main, Oct 16 2024, 01:21:29) [Clang 17.0.6 ]
# Version info: sys.version_info(major=3, minor=10, micro=15, releaselevel='final', serial=0)

# %%
import polars as pl
import clodius.tiles.bedfile as ctb
from smart_open import open

filename = '../data/GCA_002918705.1_ASM291870v1_genomic.gff.gz'
f = open(filename, 'rb', compression='disable')
print("f", f)

t = pl.read_csv(
    f, has_header=False, separator="\t", comment_char='#'
)
# Out:
# f <_io.BufferedReader name='../data/GCA_002918705.1_ASM291870v1_genomic.gff.gz'>
# Polars found a filename. Ensure you pass a path to the file instead of a python file object when possible for best performance.
# thread '<unnamed>' panicked at /Users/runner/work/polars/polars/crates/polars-io/src/csv/utils.rs:355:16:
# index out of bounds: the len is 0 but the index is 0
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[46], line 9
#       6 f = open(filename, 'rb', compression='disable')
#       7 print("f", f)
# ----> 9 t = pl.read_csv(
#      10     f, has_header=False, separator="\t", comment_char='#'
#      11 )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/polars/io/csv/functions.py:364, in read_csv(source, has_header, columns, new_columns, separator, comment_char, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines)
#     352         dtypes = {
#     353             new_to_current.get(column_name, column_name): column_dtype
#     354             for column_name, column_dtype in dtypes.items()
#     355         }
#     357 with _prepare_file_arg(
#     358     source,
#     359     encoding=encoding,
#    (...)
#     362     **storage_options,
#     363 ) as data:
# --> 364     df = pl.DataFrame._read_csv(
#     365         data,
#     366         has_header=has_header,
#     367         columns=columns if columns else projection,
#     368         separator=separator,
#     369         comment_char=comment_char,
#     370         quote_char=quote_char,
#     371         skip_rows=skip_rows,
#     372         dtypes=dtypes,
#     373         schema=schema,
#     374         null_values=null_values,
#     375         missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     376         ignore_errors=ignore_errors,
#     377         try_parse_dates=try_parse_dates,
#     378         n_threads=n_threads,
#     379         infer_schema_length=infer_schema_length,
#     380         batch_size=batch_size,
#     381         n_rows=n_rows,
#     382         encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     383         low_memory=low_memory,
#     384         rechunk=rechunk,
#     385         skip_rows_after_header=skip_rows_after_header,
#     386         row_count_name=row_count_name,
#     387         row_count_offset=row_count_offset,
#     388         sample_size=sample_size,
#     389         eol_char=eol_char,
#     390         raise_if_empty=raise_if_empty,
#     391         truncate_ragged_lines=truncate_ragged_lines,
#     392     )
#     394 if new_columns:
#     395     return _update_columns(df, new_columns)
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/polars/dataframe/frame.py:768, in DataFrame._read_csv(cls, source, has_header, columns, separator, comment_char, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_count_name, row_count_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines)
#     761         raise ValueError(
#     762             "cannot use glob patterns and integer based projection as `columns` argument"
#     763             "\n\nUse columns: List[str]"
#     764         )
#     766 projection, columns = handle_projection_columns(columns)
# --> 768 self._df = PyDataFrame.read_csv(
#     769     source,
#     770     infer_schema_length,
#     771     batch_size,
#     772     has_header,
#     773     ignore_errors,
#     774     n_rows,
#     775     skip_rows,
#     776     projection,
#     777     separator,
#     778     rechunk,
#     779     columns,
#     780     encoding,
#     781     n_threads,
#     782     path,
#     783     dtype_list,
#     784     dtype_slice,
#     785     low_memory,
#     786     comment_char,
#     787     quote_char,
#     788     processed_null_values,
#     789     missing_utf8_is_empty_string,
#     790     try_parse_dates,
#     791     skip_rows_after_header,
#     792     _prepare_row_count_args(row_count_name, row_count_offset),
#     793     sample_size=sample_size,
#     794     eol_char=eol_char,
#     795     raise_if_empty=raise_if_empty,
#     796     truncate_ragged_lines=truncate_ragged_lines,
#     797     schema=schema,
#     798 )
#     799 return self
#
# PanicException: index out of bounds: the len is 0 but the index is 0

# %%
import clodius.tiles.gff as ctg

import os.path as op
filename = op.join("../data", "GCA_002918705.1_ASM291870v1_genomic.gff.gz")

tiles = ctg.tiles(filename, ["x.0.0"])
# Out:
# /Users/pete/projects/resgen/rhodius/clodius/tiles/bigwig.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yield cid, start, chromsizes[cid]
# Polars found a filename. Ensure you pass a path to the file instead of a python file object when possible for best performance.

# %%
tiles[0][1][0]['gene-C3369_00265']
# Out:
# GeneModel(gene=Gene(id='gene-C3369_00265', start=59378, end=59454, strand='-', score=None, phase=None, attributes={'ID': 'gene-C3369_00265', 'Name': 'C3369_00265', 'gbkey': 'Gene', 'gene_biotype': 'tRNA', 'locus_tag': 'C3369_00265'}, gene_biotype='tRNA', pseudo=False), transcripts=[tRNA(id='rna-C3369_00265', start=59378, end=59454, strand='-', score=None, phase=None, attributes={'ID': 'rna-C3369_00265', 'Parent': 'gene-C3369_00265', 'anticodon': '(pos:complement(59418..59420))', 'gbkey': 'tRNA', 'inference': 'COORDINATES: profile:tRNAscan-SE:1.23', 'locus_tag': 'C3369_00265', 'product': 'tRNA-Arg'}, parent_gene_id='gene-C3369_00265', exons=[Exon(id='exon-C3369_00265-1', start=59378, end=59454, strand='-', score=None, phase=None, attributes={'ID': 'exon-C3369_00265-1', 'Parent': 'rna-C3369_00265', 'anticodon': '(pos:complement(59418..59420))', 'gbkey': 'tRNA', 'inference': 'COORDINATES: profile:tRNAscan-SE:1.23', 'locus_tag': 'C3369_00265', 'product': 'tRNA-Arg'})])])

# %%
regions = t[t[2] == 'region']
regions.head()
# Out:
#                    0        1       2  3       4  5  6  7  \
# 0     PQKR01000001.1  Genbank  region  1  776758  .  +  .
# 1482  PQKR01000010.1  Genbank  region  1  165476  .  +  .
# 1797  PQKR01000011.1  Genbank  region  1   98802  .  +  .
# 2000  PQKR01000012.1  Genbank  region  1   94569  .  +  .
# 2179  PQKR01000013.1  Genbank  region  1   54227  .  +  .
#
#                                                       8
# 0     ID=PQKR01000001.1:1..776758;Dbxref=taxon:19858...
# 1482  ID=PQKR01000010.1:1..165476;Dbxref=taxon:19858...
# 1797  ID=PQKR01000011.1:1..98802;Dbxref=taxon:198587...
# 2000  ID=PQKR01000012.1:1..94569;Dbxref=taxon:198587...
# 2179  ID=PQKR01000013.1:1..54227;Dbxref=taxon:198587...

# %%
chromsizes = pd.Series(regions[4].values, index=regions[0])

# %%
import clodius.tiles.gff as ctg

ctg.tileset_info(filename)
# Out:
# {'max_width': 4637836,
#  'max_zoom': 22,
#  'chromsizes': [['PQKR01000001.1', 776758],
#   ['PQKR01000010.1', 165476],
#   ['PQKR01000011.1', 98802],
#   ['PQKR01000012.1', 94569],
#   ['PQKR01000013.1', 54227],
#   ['PQKR01000014.1', 45015],
#   ['PQKR01000015.1', 42350],
#   ['PQKR01000016.1', 35661],
#   ['PQKR01000017.1', 35096],
#   ['PQKR01000018.1', 27229],
#   ['PQKR01000019.1', 26340],
#   ['PQKR01000002.1', 753015],
#   ['PQKR01000020.1', 25534],
#   ['PQKR01000021.1', 21148],
#   ['PQKR01000022.1', 20532],
#   ['PQKR01000023.1', 19917],
#   ['PQKR01000024.1', 18379],
#   ['PQKR01000025.1', 16854],
#   ['PQKR01000026.1', 15198],
#   ['PQKR01000027.1', 9947],
#   ['PQKR01000028.1', 9581],
#   ['PQKR01000029.1', 7142],
#   ['PQKR01000003.1', 523976],
#   ['PQKR01000030.1', 6286],
#   ['PQKR01000031.1', 5872],
#   ['PQKR01000032.1', 5084],
#   ['PQKR01000033.1', 5021],
#   ['PQKR01000034.1', 4481],
#   ['PQKR01000035.1', 4433],
#   ['PQKR01000036.1', 4220],
#   ['PQKR01000037.1', 3213],
#   ['PQKR01000038.1', 2947],
#   ['PQKR01000039.1', 2622],
#   ['PQKR01000004.1', 410212],
#   ['PQKR01000040.1', 1594],
#   ['PQKR01000041.1', 1405],
#   ['PQKR01000042.1', 1176],
#   ['PQKR01000043.1', 1159],
#   ['PQKR01000044.1', 1105],
#   ['PQKR01000045.1', 832],
#   ['PQKR01000046.1', 821],
#   ['PQKR01000047.1', 722],
#   ['PQKR01000048.1', 754],
#   ['PQKR01000049.1', 641],
#   ['PQKR01000005.1', 409798],
#   ['PQKR01000050.1', 566],
#   ['PQKR01000051.1', 563],
#   ['PQKR01000006.1', 281993],
#   ['PQKR01000007.1', 231481],
#   ['PQKR01000008.1', 222373],
#   ['PQKR01000009.1', 183716]],
#  'min_pos': [0],
#  'max_pos': [4637836]}

# %%
# Out:
# {'max_width': 4637836,
#  'max_zoom': 22,
#  'chromsizes': [['PQKR01000001.1', 776758],
#   ['PQKR01000010.1', 165476],
#   ['PQKR01000011.1', 98802],
#   ['PQKR01000012.1', 94569],
#   ['PQKR01000013.1', 54227],
#   ['PQKR01000014.1', 45015],
#   ['PQKR01000015.1', 42350],
#   ['PQKR01000016.1', 35661],
#   ['PQKR01000017.1', 35096],
#   ['PQKR01000018.1', 27229],
#   ['PQKR01000019.1', 26340],
#   ['PQKR01000002.1', 753015],
#   ['PQKR01000020.1', 25534],
#   ['PQKR01000021.1', 21148],
#   ['PQKR01000022.1', 20532],
#   ['PQKR01000023.1', 19917],
#   ['PQKR01000024.1', 18379],
#   ['PQKR01000025.1', 16854],
#   ['PQKR01000026.1', 15198],
#   ['PQKR01000027.1', 9947],
#   ['PQKR01000028.1', 9581],
#   ['PQKR01000029.1', 7142],
#   ['PQKR01000003.1', 523976],
#   ['PQKR01000030.1', 6286],
#   ['PQKR01000031.1', 5872],
#   ['PQKR01000032.1', 5084],
#   ['PQKR01000033.1', 5021],
#   ['PQKR01000034.1', 4481],
#   ['PQKR01000035.1', 4433],
#   ['PQKR01000036.1', 4220],
#   ['PQKR01000037.1', 3213],
#   ['PQKR01000038.1', 2947],
#   ['PQKR01000039.1', 2622],
#   ['PQKR01000004.1', 410212],
#   ['PQKR01000040.1', 1594],
#   ['PQKR01000041.1', 1405],
#   ['PQKR01000042.1', 1176],
#   ['PQKR01000043.1', 1159],
#   ['PQKR01000044.1', 1105],
#   ['PQKR01000045.1', 832],
#   ['PQKR01000046.1', 821],
#   ['PQKR01000047.1', 722],
#   ['PQKR01000048.1', 754],
#   ['PQKR01000049.1', 641],
#   ['PQKR01000005.1', 409798],
#   ['PQKR01000050.1', 566],
#   ['PQKR01000051.1', 563],
#   ['PQKR01000006.1', 281993],
#   ['PQKR01000007.1', 231481],
#   ['PQKR01000008.1', 222373],
#   ['PQKR01000009.1', 183716]],
#  'min_pos': [0],
#  'max_pos': [4637836]}
